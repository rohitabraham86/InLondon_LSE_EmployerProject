# %%
# Import necessary libraries. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Central London Data Set

# %%
# Importing Central dataset.
cl = pd.read_csv('Central London.csv')

# View the DataFrame.
cl
# Out:
#         Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# ...                                ...                          ...       ...
# 1048361                            NaN                          NaN       NaN
# 1048362                            NaN                          NaN       NaN
# 1048363                            NaN                          NaN       NaN
# 1048364                            NaN                          NaN       NaN
# 1048365                            NaN                          NaN       NaN
#
#                                    Location    Survey date Weather  \
# 0        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 1        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 2        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 3        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 4        Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# ...                                     ...            ...     ...
# 1048361                                 NaN            NaN     NaN
# 1048362                                 NaN            NaN     NaN
# 1048363                                 NaN            NaN     NaN
# 1048364                                 NaN            NaN     NaN
# 1048365                                 NaN            NaN     NaN
#
#                 Time                       Period   Direction  Start hour  \
# 0        0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1        0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2        0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3        0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4        0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...              ...                          ...         ...         ...
# 1048361          NaN                          NaN         NaN         NaN
# 1048362          NaN                          NaN         NaN         NaN
# 1048363          NaN                          NaN         NaN         NaN
# 1048364          NaN                          NaN         NaN         NaN
# 1048365          NaN                          NaN         NaN         NaN
#
#          Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                 0.0                       0.0                         0.0
# 1                15.0                      15.0                         0.0
# 2                30.0                      35.0                         0.0
# 3                45.0                      59.0                         2.0
# 4                 0.0                      73.0                         0.0
# ...               ...                       ...                         ...
# 1048361           NaN                       NaN                         NaN
# 1048362           NaN                       NaN                         NaN
# 1048363           NaN                       NaN                         NaN
# 1048364           NaN                       NaN                         NaN
# 1048365           NaN                       NaN                         NaN
#
#          Total cycles  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0                 0.0          NaN          NaN          NaN
# 1                15.0          NaN          NaN          NaN
# 2                35.0          NaN          NaN          NaN
# 3                61.0          NaN          NaN          NaN
# 4                73.0          NaN          NaN          NaN
# ...               ...          ...          ...          ...
# 1048361           NaN          NaN          NaN          NaN
# 1048362           NaN          NaN          NaN          NaN
# 1048363           NaN          NaN          NaN          NaN
# 1048364           NaN          NaN          NaN          NaN
# 1048365           NaN          NaN          NaN          NaN
#
# [1048366 rows x 17 columns]

# %%
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048366 entries, 0 to 1048365
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     748007 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758099 non-null  float64
#  12  Number of cycle hire bikes      758099 non-null  float64
#  13  Total cycles                    758163 non-null  float64
#  14  Unnamed: 14                     0 non-null       float64
#  15  Unnamed: 15                     0 non-null       float64
#  16  Unnamed: 16                     0 non-null       float64
# dtypes: float64(8), object(9)
# memory usage: 136.0+ MB

# %%
# Dropping the columns which has 0 non-null values.
cl = cl.drop(['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'], axis=1)

# %%
cl['Survey wave (Year)'] = cl['Survey wave (calendar quarter)'].str.split().str[0]

# %%
from datetime import datetime, timedelta

# %%
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048366 entries, 0 to 1048365
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     748007 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758099 non-null  float64
#  12  Number of cycle hire bikes      758099 non-null  float64
#  13  Total cycles                    758163 non-null  float64
#  14  Survey wave (Year)              758163 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 120.0+ MB

# %%
# Dropping NaN values from the dataset.
cl_drp = cl.dropna()

# %%
cl_drp
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# ...                               ...                          ...       ...
# 758158    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758159    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758160    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758161    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758162    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
#
#                                   Location    Survey date Weather  \
# 0       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 1       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 2       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 3       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 4       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# ...                                    ...            ...     ...
# 758158                           Haymarket  mar, 21/12/21     Dry
# 758159                           Haymarket  mar, 21/12/21     Dry
# 758160                           Haymarket  mar, 21/12/21     Dry
# 758161                           Haymarket  mar, 21/12/21     Dry
# 758162                           Haymarket  mar, 21/12/21     Dry
#
#                Time                       Period   Direction  Start hour  \
# 0       0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1       0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2       0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3       0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4       0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...             ...                          ...         ...         ...
# 758158  2045 - 2100        Evening (19:00-22:00)  Southbound        20.0
# 758159  2100 - 2115        Evening (19:00-22:00)  Southbound        21.0
# 758160  2115 - 2130        Evening (19:00-22:00)  Southbound        21.0
# 758161  2130 - 2145        Evening (19:00-22:00)  Southbound        21.0
# 758162  2145 - 2200        Evening (19:00-22:00)  Southbound        21.0
#
#         Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                0.0                       0.0                         0.0
# 1               15.0                      15.0                         0.0
# 2               30.0                      35.0                         0.0
# 3               45.0                      59.0                         2.0
# 4                0.0                      73.0                         0.0
# ...              ...                       ...                         ...
# 758158          45.0                      22.0                         1.0
# 758159           0.0                      20.0                         0.0
# 758160          15.0                      16.0                         1.0
# 758161          30.0                      10.0                         1.0
# 758162          45.0                      12.0                         2.0
#
#         Total cycles Survey wave (Year)
# 0                0.0               2014
# 1               15.0               2014
# 2               35.0               2014
# 3               61.0               2014
# 4               73.0               2014
# ...              ...                ...
# 758158          23.0               2021
# 758159          20.0               2021
# 758160          17.0               2021
# 758161          11.0               2021
# 758162          14.0               2021
#
# [743317 rows x 15 columns]

# %%
cl_drp[['Start_time', 'End_time']] = cl_drp['Time'].str.split(" - ", expand=True)
cl_drp['Start_time'] = pd.to_datetime(cl_drp['Start_time'], format='%H%M')
cl_drp['End_time'] = pd.to_datetime(cl_drp['End_time'], format='%H%M')
cl_drp['Duration'] = cl_drp['End_time'] - cl_drp['Start_time']

# %%
cl_drp
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# ...                               ...                          ...       ...
# 758158    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758159    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758160    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758161    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758162    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
#
#                                   Location    Survey date Weather  \
# 0       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 1       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 2       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 3       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 4       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# ...                                    ...            ...     ...
# 758158                           Haymarket  mar, 21/12/21     Dry
# 758159                           Haymarket  mar, 21/12/21     Dry
# 758160                           Haymarket  mar, 21/12/21     Dry
# 758161                           Haymarket  mar, 21/12/21     Dry
# 758162                           Haymarket  mar, 21/12/21     Dry
#
#                Time                       Period   Direction  Start hour  \
# 0       0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1       0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2       0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3       0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4       0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...             ...                          ...         ...         ...
# 758158  2045 - 2100        Evening (19:00-22:00)  Southbound        20.0
# 758159  2100 - 2115        Evening (19:00-22:00)  Southbound        21.0
# 758160  2115 - 2130        Evening (19:00-22:00)  Southbound        21.0
# 758161  2130 - 2145        Evening (19:00-22:00)  Southbound        21.0
# 758162  2145 - 2200        Evening (19:00-22:00)  Southbound        21.0
#
#         Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                0.0                       0.0                         0.0
# 1               15.0                      15.0                         0.0
# 2               30.0                      35.0                         0.0
# 3               45.0                      59.0                         2.0
# 4                0.0                      73.0                         0.0
# ...              ...                       ...                         ...
# 758158          45.0                      22.0                         1.0
# 758159           0.0                      20.0                         0.0
# 758160          15.0                      16.0                         1.0
# 758161          30.0                      10.0                         1.0
# 758162          45.0                      12.0                         2.0
#
#         Total cycles Survey wave (Year)          Start_time  \
# 0                0.0               2014 1900-01-01 06:00:00
# 1               15.0               2014 1900-01-01 06:15:00
# 2               35.0               2014 1900-01-01 06:30:00
# 3               61.0               2014 1900-01-01 06:45:00
# 4               73.0               2014 1900-01-01 07:00:00
# ...              ...                ...                 ...
# 758158          23.0               2021 1900-01-01 20:45:00
# 758159          20.0               2021 1900-01-01 21:00:00
# 758160          17.0               2021 1900-01-01 21:15:00
# 758161          11.0               2021 1900-01-01 21:30:00
# 758162          14.0               2021 1900-01-01 21:45:00
#
#                   End_time        Duration
# 0      1900-01-01 06:15:00 0 days 00:15:00
# 1      1900-01-01 06:30:00 0 days 00:15:00
# 2      1900-01-01 06:45:00 0 days 00:15:00
# 3      1900-01-01 07:00:00 0 days 00:15:00
# 4      1900-01-01 07:15:00 0 days 00:15:00
# ...                    ...             ...
# 758158 1900-01-01 21:00:00 0 days 00:15:00
# 758159 1900-01-01 21:15:00 0 days 00:15:00
# 758160 1900-01-01 21:30:00 0 days 00:15:00
# 758161 1900-01-01 21:45:00 0 days 00:15:00
# 758162 1900-01-01 22:00:00 0 days 00:15:00
#
# [743317 rows x 18 columns]

# %%
cl_drp['Start_time'] = cl_drp['Start_time'].apply(lambda x: x.time())
cl_drp['End_time'] = cl_drp['End_time'].apply(lambda x: x.time())

# %%
# Duration in miniutes.
cl_drp['Duration_min'] = cl_drp['Duration'].dt.total_seconds()/60

# %%
cl_drp
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4             2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# ...                               ...                          ...       ...
# 758158    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758159    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758160    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758161    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
# 758162    2021 Q4 (October-December)                    2021-22 Q3  CENCY702
#
#                                   Location    Survey date Weather  \
# 0       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 1       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 2       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 3       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# 4       Millbank (south of Thorney Street)  ven, 24/01/14     Dry
# ...                                    ...            ...     ...
# 758158                           Haymarket  mar, 21/12/21     Dry
# 758159                           Haymarket  mar, 21/12/21     Dry
# 758160                           Haymarket  mar, 21/12/21     Dry
# 758161                           Haymarket  mar, 21/12/21     Dry
# 758162                           Haymarket  mar, 21/12/21     Dry
#
#                Time                       Period   Direction  Start hour  \
# 0       0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1       0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2       0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3       0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4       0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...             ...                          ...         ...         ...
# 758158  2045 - 2100        Evening (19:00-22:00)  Southbound        20.0
# 758159  2100 - 2115        Evening (19:00-22:00)  Southbound        21.0
# 758160  2115 - 2130        Evening (19:00-22:00)  Southbound        21.0
# 758161  2130 - 2145        Evening (19:00-22:00)  Southbound        21.0
# 758162  2145 - 2200        Evening (19:00-22:00)  Southbound        21.0
#
#         Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                0.0                       0.0                         0.0
# 1               15.0                      15.0                         0.0
# 2               30.0                      35.0                         0.0
# 3               45.0                      59.0                         2.0
# 4                0.0                      73.0                         0.0
# ...              ...                       ...                         ...
# 758158          45.0                      22.0                         1.0
# 758159           0.0                      20.0                         0.0
# 758160          15.0                      16.0                         1.0
# 758161          30.0                      10.0                         1.0
# 758162          45.0                      12.0                         2.0
#
#         Total cycles Survey wave (Year) Start_time  End_time        Duration  \
# 0                0.0               2014   06:00:00  06:15:00 0 days 00:15:00
# 1               15.0               2014   06:15:00  06:30:00 0 days 00:15:00
# 2               35.0               2014   06:30:00  06:45:00 0 days 00:15:00
# 3               61.0               2014   06:45:00  07:00:00 0 days 00:15:00
# 4               73.0               2014   07:00:00  07:15:00 0 days 00:15:00
# ...              ...                ...        ...       ...             ...
# 758158          23.0               2021   20:45:00  21:00:00 0 days 00:15:00
# 758159          20.0               2021   21:00:00  21:15:00 0 days 00:15:00
# 758160          17.0               2021   21:15:00  21:30:00 0 days 00:15:00
# 758161          11.0               2021   21:30:00  21:45:00 0 days 00:15:00
# 758162          14.0               2021   21:45:00  22:00:00 0 days 00:15:00
#
#         Duration_min
# 0               15.0
# 1               15.0
# 2               15.0
# 3               15.0
# 4               15.0
# ...              ...
# 758158          15.0
# 758159          15.0
# 758160          15.0
# 758161          15.0
# 758162          15.0
#
# [743317 rows x 19 columns]

# %%
# check the column as to why it is not splitting from this 'ven, 24/01/14'.
pd.to_datetime(cl_drp['Survey date'], errors='coerce')
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 758158   NaT
# 758159   NaT
# 758160   NaT
# 758161   NaT
# 758162   NaT
# Name: Survey date, Length: 743317, dtype: datetime64[ns]

# %%
# To remove spaces from the start and end of the strings.
cl_drp['Survey date'] = cl_drp['Survey date'].str.strip()

# %%
# Removing the 1st 4 characters in Survey Date.
cl_drp["Survey date"] = cl_drp["Survey date"].str[4:]

# %%
# Converting non-matching formats to NaT
cl_drp["Survey date"] = pd.to_datetime(cl_drp["Survey date"], errors='coerce')

# %%
# Count the number of missing values in the 'Survey date' column
missing_values = cl_drp['Survey date'].isnull().sum()
print(missing_values)
# Out:
# 256

# %%
# Dropping the missing values.
cl_drp = cl_drp.dropna(subset=['Survey date'])

# %%
#converting to datetime format.
cl_drp["Survey date"] = pd.to_datetime(cl_drp["Survey date"], format='%d/%m/%y', errors='coerce')

# %%
# Splitting date into day, month, year.
cl_drp['day'] = pd.DatetimeIndex(cl_drp['Survey date']).day
cl_drp['month'] = pd.DatetimeIndex(cl_drp['Survey date']).month
cl_drp['year'] = pd.DatetimeIndex(cl_drp['Survey date']).year

# %%
# Changing to all lower case.
cl_drp[['Weather']] = cl_drp[['Weather']].apply(lambda x: x.str.lower())

# %%
# Dropping the columns which is not required.
cl_drp = cl_drp.drop(['Survey wave (calendar quarter)', 'Equivalent financial quarter',
                     'Survey date', 'Time', 'Start hour', 'Start minute', 'Survey wave (Year)', 'Duration'], axis=1)

# %%
# Checking the dataframe.
cl_drp
# Out:
#          Site ID                            Location Weather  \
# 0       CENCY001  Millbank (south of Thorney Street)     dry
# 1       CENCY001  Millbank (south of Thorney Street)     dry
# 2       CENCY001  Millbank (south of Thorney Street)     dry
# 3       CENCY001  Millbank (south of Thorney Street)     dry
# 4       CENCY001  Millbank (south of Thorney Street)     dry
# ...          ...                                 ...     ...
# 758158  CENCY702                           Haymarket     dry
# 758159  CENCY702                           Haymarket     dry
# 758160  CENCY702                           Haymarket     dry
# 758161  CENCY702                           Haymarket     dry
# 758162  CENCY702                           Haymarket     dry
#
#                              Period   Direction  Number of private cycles  \
# 0       Early Morning (06:00-07:00)  Northbound                       0.0
# 1       Early Morning (06:00-07:00)  Northbound                      15.0
# 2       Early Morning (06:00-07:00)  Northbound                      35.0
# 3       Early Morning (06:00-07:00)  Northbound                      59.0
# 4             AM peak (07:00-10:00)  Northbound                      73.0
# ...                             ...         ...                       ...
# 758158        Evening (19:00-22:00)  Southbound                      22.0
# 758159        Evening (19:00-22:00)  Southbound                      20.0
# 758160        Evening (19:00-22:00)  Southbound                      16.0
# 758161        Evening (19:00-22:00)  Southbound                      10.0
# 758162        Evening (19:00-22:00)  Southbound                      12.0
#
#         Number of cycle hire bikes  Total cycles Start_time  End_time  \
# 0                              0.0           0.0   06:00:00  06:15:00
# 1                              0.0          15.0   06:15:00  06:30:00
# 2                              0.0          35.0   06:30:00  06:45:00
# 3                              2.0          61.0   06:45:00  07:00:00
# 4                              0.0          73.0   07:00:00  07:15:00
# ...                            ...           ...        ...       ...
# 758158                         1.0          23.0   20:45:00  21:00:00
# 758159                         0.0          20.0   21:00:00  21:15:00
# 758160                         1.0          17.0   21:15:00  21:30:00
# 758161                         1.0          11.0   21:30:00  21:45:00
# 758162                         2.0          14.0   21:45:00  22:00:00
#
#         Duration_min  day  month  year
# 0               15.0   24      1  2014
# 1               15.0   24      1  2014
# 2               15.0   24      1  2014
# 3               15.0   24      1  2014
# 4               15.0   24      1  2014
# ...              ...  ...    ...   ...
# 758158          15.0   21     12  2021
# 758159          15.0   21     12  2021
# 758160          15.0   21     12  2021
# 758161          15.0   21     12  2021
# 758162          15.0   21     12  2021
#
# [743061 rows x 14 columns]

# %%
cl_drp['Weather'].unique()
# Out:
# array(['dry', 'wet', 'rain', 'fine', 'damp', 'showery', 'cold/rain',
#        'light rain', 'slightly wet', 'rain stopped', 'road wet',
#        'almost dry', 'light shower', 'rain damp', 'rain dry', 'wet damp',
#        'very wet', 'v wet', 'wet - dry', 'dry - wet', 'dry - rain',
#        'damp - rain', 'wet/ dry', 's. wet', 'v. wet',
#        'wet intermittently', 'cloudy/ rain', 'windy/ rain', 'cold/ rain',
#        'drizzle', 'lt rain', 'dry & sunny', 'spitting', 'showers',
#        'cloudy', 'sunny', 'light showers', 'hazy', 'shower', 'foggy',
#        'dull', 'wet/dry', 'kdry', 'partly cloudy', 'rainy', 'wet t',
#        'sun', 'fair', 'slight drizzle', 'very heavy rain', 'mild',
#        'wet + windy', 'blustery', 'rain/wind', 'fine windy', 'dry windy',
#        'dry wet road', 'deluge', 'dry/wet', 'dry & wet', 'v light rain',
#        'dry a.m wet p.m', 'wet road', 'cold', 'cloudy/rain',
#        'wet & windy', 'windy', 'down pour', 'dry & very windy', 'mist',
#        'cold windy dry', 'drty', 'dry (windy)', 'wet (windy)',
#        'fine (windy)', 'road drying sun out', 'dryish', 'wetish',
#        'light shrs', 'dry & windy', 'some showers', 'rains', 'dry/sunny',
#        'dry/cloudy', 'dry/hot', 'sunny/rainy', 'very hot dry',
#        'sunny cloudy', 'dry dark', 'dark sunny', 'dark dry', 'dark',
#        'fine drizzle', 'heavy showers', 'd', 'wetr', 'showers mix',
#        'dry/good', 'good/dry', 'dry mon', 'dry wed', 'dry thu', 'dry fri',
#        'sun/rain', 'rain/dry', 'dry y', 'v light shrs',
#        'occasional lt snow shrs', 'l/rain', 'rain/cloudy', 'cold/dry',
#        'wet and very windy', 'rain stopped-dry', 'dry/windy',
#        'shower/wet', 'v lt rain', 'thunder', 'heavy rain', 'heavy shower',
#        'hail', 'rain & thunder', 'rain-heavy', 'v.light rain',
#        'dry (+brief speels of drizzle', 'wetter', 'wet (spitting)',
#        'getting wet', 'h rain', 'wet/rain', 'drizzly rain', 'v.wet',
#        'ddry', 'wert', '(rain after)', 'damp & drizzly',
#        'dry road wet with leaves', 'wet drizzle', 'dy',
#        'some heavy showers', 'no rain wet roads', 'dry but wet roads',
#        'very cold/dry', 'very light rain', 'sunny/dry', 'foggy/v cold',
#        'dry/cold', 'dry/sunny/cold', 'sleet', 'fine v cold', 'fine cold',
#        'hail shower', 'light drizzle', 'dry (frost & fog)',
#        'dry/wet road surface', 'snow', 'v cold showers', 'cold/showery',
#        'light showers inc some hail', 'v light showers', 'warm + dry',
#        'v. light rain', 'cloudy/hail', 'wet/cloudy', 'sun/cloudy',
#        'hot/dry', 'cloudy/dry', 'wet/sunny', 'dry road still wet',
#        'snowing', '2 snowflakes otherwise dry', 'dry + wet',
#        'rain/drizzle', 'wet/ snowing', 'wet-dry', 'heavy snow',
#        'cold dry', 'dry/drizzly', 'dry & cold', 'wet/light showers',
#        'wet/drizzle', 'wet/damp', 'drizzle/wet', 'sunny/cloudy',
#        'dry and fine', 'dry sunny', 'cold wind', 'wed', 'dry and sunny',
#        'dry and warm', 'fine and dry', 'warm + sunny', 'warm and humid',
#        'warm and windy', 'cloudy/sunny', 'overcast and dull',
#        'cloudy and warm', 'sunny periods and warm', 'wet and windy',
#        'dry and windy', 'dry and very windy', 'hot & sunny',
#        'warm sunny and windy', 'hot and sunny', 'hot and humid',
#        'mild and sunny', 'warm and overcast', 'drizzling', 'drizzle damp',
#        'sunny & windy', 'windy dry', 'windy showery', 'dry-wet',
#        'wet + dry', 'cloud/rain', 'cloudy/windy', 'windy/cloudy',
#        'dry/drizzle', 'cloudy/drizzle', 'v.light drizzle',
#        'very light drizzle', 'v light drizzle', 'dry/gusty', 'drying up',
#        'wet again', 'really wet', 'dry but wet road', 'coldish',
#        'overcast', 'cold sunny rain', 'wet first then dry',
#        'wetr first then dry', 'windy/dry', 'very windy & cold',
#        'dry & mild', 'dry but a bit windy', 'sunny cold',
#        'high winds & spits of rain', 'dry with intermitent rain',
#        'cold at first then warm/sunny', 'periods of rain quite windy',
#        'warm & sunny chilly later', '(drizzle)', 'damp/misty/wet',
#        'dry/windy/strong wind', 'dry/very windy', 'drizzle/showers',
#        'dry but rain threatening', 'slight drizzle till end',
#        'hot + humid', 'damp/misty', 'cold & dry early rain later',
#        'heavy showers throughout day', 'drizzle/rain', 'windy/drizzle',
#        'dry 3/4 dry', 'intermitent light showers',
#        'intermitent light rain', 'cold then dry and windy',
#        'dry and overcast', 'dry + sunny', 'a few rain showers',
#        'warm + sunny cloudy + windy', 'sunny until evening but windy',
#        'winds rather chilly', 'drizzly', 'wet light hailstone', 'warm',
#        'rain looking likely', 'a few drops of rain',
#        'sunny but very windy', 'now starts to get chilly',
#        'very cold sunny but windy', 'warm & sunny but windy & cold',
#        'steady rain', 'sun/clouds', 'a bit chilly at first',
#        'warm with a slight wind', 'fine + dry chilly at first',
#        'fine & sunny', 'wet ', 'storm'], dtype=object)

# %%
# create a new column with the category
cl_drp['Category'] = 'Other'
cl_drp.loc[cl_drp['Weather'].str.contains(
    'wet|rain|thunder|shower|drizzly|drizzle|deluge|hail', case=False), 'Category'] = 'Wet'
cl_drp.loc[cl_drp['Weather'].str.contains(
    'dry|sun|clear', case=False), 'Category'] = 'Dry'
cl_drp.loc[cl_drp['Weather'].str.contains(
    'wind|gale|windy', case=False), 'Category'] = 'Windy'

# %%
# Creating a new column
cl_drp = cl_drp.assign(area='Central London')

# %%
# Checking the dataframe.

cl_drp
# Out:
#          Site ID                            Location Weather  \
# 0       CENCY001  Millbank (south of Thorney Street)     dry
# 1       CENCY001  Millbank (south of Thorney Street)     dry
# 2       CENCY001  Millbank (south of Thorney Street)     dry
# 3       CENCY001  Millbank (south of Thorney Street)     dry
# 4       CENCY001  Millbank (south of Thorney Street)     dry
# ...          ...                                 ...     ...
# 758158  CENCY702                           Haymarket     dry
# 758159  CENCY702                           Haymarket     dry
# 758160  CENCY702                           Haymarket     dry
# 758161  CENCY702                           Haymarket     dry
# 758162  CENCY702                           Haymarket     dry
#
#                              Period   Direction  Number of private cycles  \
# 0       Early Morning (06:00-07:00)  Northbound                       0.0
# 1       Early Morning (06:00-07:00)  Northbound                      15.0
# 2       Early Morning (06:00-07:00)  Northbound                      35.0
# 3       Early Morning (06:00-07:00)  Northbound                      59.0
# 4             AM peak (07:00-10:00)  Northbound                      73.0
# ...                             ...         ...                       ...
# 758158        Evening (19:00-22:00)  Southbound                      22.0
# 758159        Evening (19:00-22:00)  Southbound                      20.0
# 758160        Evening (19:00-22:00)  Southbound                      16.0
# 758161        Evening (19:00-22:00)  Southbound                      10.0
# 758162        Evening (19:00-22:00)  Southbound                      12.0
#
#         Number of cycle hire bikes  Total cycles Start_time  End_time  \
# 0                              0.0           0.0   06:00:00  06:15:00
# 1                              0.0          15.0   06:15:00  06:30:00
# 2                              0.0          35.0   06:30:00  06:45:00
# 3                              2.0          61.0   06:45:00  07:00:00
# 4                              0.0          73.0   07:00:00  07:15:00
# ...                            ...           ...        ...       ...
# 758158                         1.0          23.0   20:45:00  21:00:00
# 758159                         0.0          20.0   21:00:00  21:15:00
# 758160                         1.0          17.0   21:15:00  21:30:00
# 758161                         1.0          11.0   21:30:00  21:45:00
# 758162                         2.0          14.0   21:45:00  22:00:00
#
#         Duration_min  day  month  year Category            area
# 0               15.0   24      1  2014      Dry  Central London
# 1               15.0   24      1  2014      Dry  Central London
# 2               15.0   24      1  2014      Dry  Central London
# 3               15.0   24      1  2014      Dry  Central London
# 4               15.0   24      1  2014      Dry  Central London
# ...              ...  ...    ...   ...      ...             ...
# 758158          15.0   21     12  2021      Dry  Central London
# 758159          15.0   21     12  2021      Dry  Central London
# 758160          15.0   21     12  2021      Dry  Central London
# 758161          15.0   21     12  2021      Dry  Central London
# 758162          15.0   21     12  2021      Dry  Central London
#
# [743061 rows x 16 columns]

# %%
cl_drp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743061 entries, 0 to 758162
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Site ID                     743061 non-null  object
#  1   Location                    743061 non-null  object
#  2   Weather                     743061 non-null  object
#  3   Period                      743061 non-null  object
#  4   Direction                   743061 non-null  object
#  5   Number of private cycles    743061 non-null  float64
#  6   Number of cycle hire bikes  743061 non-null  float64
#  7   Total cycles                743061 non-null  float64
#  8   Start_time                  743061 non-null  object
#  9   End_time                    743061 non-null  object
#  10  Duration_min                743061 non-null  float64
#  11  day                         743061 non-null  int64
#  12  month                       743061 non-null  int64
#  13  year                        743061 non-null  int64
#  14  Category                    743061 non-null  object
#  15  area                        743061 non-null  object
# dtypes: float64(4), int64(3), object(9)
# memory usage: 96.4+ MB

# %%
cl_drp['Category'].value_counts()
# Out:
# Dry      625770
# Wet       88758
# Other     26433
# Windy      2100
# Name: Category, dtype: int64

# %%
cl_drp['Duration_min'].unique()
# Out:
# array([15.])

# %% [markdown]
# ### Inner London Data Set

# %%
# Importing Inner London dataset.
il = pd.read_csv('Inner London.csv')

# View the DataFrame.
il
# Out:
#         Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0                   2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1                   2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2                   2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3                   2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4                   2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# ...                    ...       ...         ...            ...     ...
# 615163                 NaN       NaN         NaN            NaN     NaN
# 615164                 NaN       NaN         NaN            NaN     NaN
# 615165                 NaN       NaN         NaN            NaN     NaN
# 615166                 NaN       NaN         NaN            NaN     NaN
# 615167                 NaN       NaN         NaN            NaN     NaN
#
#                Time                       Period   Direction  Start hour  \
# 0       0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1       0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2       0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3       0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4       0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...             ...                          ...         ...         ...
# 615163          NaN                          NaN         NaN         NaN
# 615164          NaN                          NaN         NaN         NaN
# 615165          NaN                          NaN         NaN         NaN
# 615166          NaN                          NaN         NaN         NaN
# 615167          NaN                          NaN         NaN         NaN
#
#         Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                0.0                       1.0                         0.0
# 1               15.0                       2.0                         0.0
# 2               30.0                       2.0                         0.0
# 3               45.0                       4.0                         0.0
# 4                0.0                       4.0                         0.0
# ...              ...                       ...                         ...
# 615163           NaN                       NaN                         NaN
# 615164           NaN                       NaN                         NaN
# 615165           NaN                       NaN                         NaN
# 615166           NaN                       NaN                         NaN
# 615167           NaN                       NaN                         NaN
#
#         Total cycles
# 0                1.0
# 1                2.0
# 2                2.0
# 3                4.0
# 4                4.0
# ...              ...
# 615163           NaN
# 615164           NaN
# 615165           NaN
# 615166           NaN
# 615167           NaN
#
# [615168 rows x 13 columns]

# %%
il.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615168 entries, 0 to 615167
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Survey wave (year)          523776 non-null  float64
#  1   Site ID                     523776 non-null  object
#  2   Location                    523776 non-null  object
#  3   Survey date                 521024 non-null  object
#  4   Weather                     519102 non-null  object
#  5   Time                        523770 non-null  object
#  6   Period                      523770 non-null  object
#  7   Direction                   523776 non-null  object
#  8   Start hour                  523770 non-null  float64
#  9   Start minute                523770 non-null  float64
#  10  Number of private cycles    523776 non-null  float64
#  11  Number of cycle hire bikes  523776 non-null  float64
#  12  Total cycles                523776 non-null  float64
# dtypes: float64(6), object(7)
# memory usage: 61.0+ MB

# %%
missing_values = il.isna().sum()
print(missing_values)
# Out:
# Survey wave (year)            91392
# Site ID                       91392
# Location                      91392
# Survey date                   94144
# Weather                       96066
# Time                          91398
# Period                        91398
# Direction                     91392
# Start hour                    91398
# Start minute                  91398
# Number of private cycles      91392
# Number of cycle hire bikes    91392
# Total cycles                  91392
# dtype: int64

# %%
# checking missing values.
missing_values_df = il.isna()
missing_values_df
# Out:
#         Survey wave (year)  Site ID  Location  Survey date  Weather   Time  \
# 0                    False    False     False        False    False  False
# 1                    False    False     False        False    False  False
# 2                    False    False     False        False    False  False
# 3                    False    False     False        False    False  False
# 4                    False    False     False        False    False  False
# ...                    ...      ...       ...          ...      ...    ...
# 615163                True     True      True         True     True   True
# 615164                True     True      True         True     True   True
# 615165                True     True      True         True     True   True
# 615166                True     True      True         True     True   True
# 615167                True     True      True         True     True   True
#
#         Period  Direction  Start hour  Start minute  Number of private cycles  \
# 0        False      False       False         False                     False
# 1        False      False       False         False                     False
# 2        False      False       False         False                     False
# 3        False      False       False         False                     False
# 4        False      False       False         False                     False
# ...        ...        ...         ...           ...                       ...
# 615163    True       True        True          True                      True
# 615164    True       True        True          True                      True
# 615165    True       True        True          True                      True
# 615166    True       True        True          True                      True
# 615167    True       True        True          True                      True
#
#         Number of cycle hire bikes  Total cycles
# 0                            False         False
# 1                            False         False
# 2                            False         False
# 3                            False         False
# 4                            False         False
# ...                            ...           ...
# 615163                        True          True
# 615164                        True          True
# 615165                        True          True
# 615166                        True          True
# 615167                        True          True
#
# [615168 rows x 13 columns]

# %%
# Dropping NaN values from the dataset.
il_drp = il.dropna()

# %%
# Check dataframe.
il_drp
# Out:
#         Survey wave (year)   Site ID       Location    Survey date Weather  \
# 0                   2015.0  INNCY001     Grove Road  mer, 20/05/15     Dry
# 1                   2015.0  INNCY001     Grove Road  mer, 20/05/15     Dry
# 2                   2015.0  INNCY001     Grove Road  mer, 20/05/15     Dry
# 3                   2015.0  INNCY001     Grove Road  mer, 20/05/15     Dry
# 4                   2015.0  INNCY001     Grove Road  mer, 20/05/15     Dry
# ...                    ...       ...            ...            ...     ...
# 523771              2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523772              2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523773              2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523774              2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
# 523775              2021.0  INNCY597  Augustus Road  mer, 26/05/21     Dry
#
#                Time                       Period   Direction  Start hour  \
# 0       0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1       0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2       0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3       0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4       0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...             ...                          ...         ...         ...
# 523771  2045 - 2100        Evening (19:00-22:00)   Westbound        20.0
# 523772  2100 - 2115        Evening (19:00-22:00)   Westbound        21.0
# 523773  2115 - 2130        Evening (19:00-22:00)   Westbound        21.0
# 523774  2130 - 2145        Evening (19:00-22:00)   Westbound        21.0
# 523775  2145 - 2200        Evening (19:00-22:00)   Westbound        21.0
#
#         Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                0.0                       1.0                         0.0
# 1               15.0                       2.0                         0.0
# 2               30.0                       2.0                         0.0
# 3               45.0                       4.0                         0.0
# 4                0.0                       4.0                         0.0
# ...              ...                       ...                         ...
# 523771          45.0                       3.0                         0.0
# 523772           0.0                       2.0                         0.0
# 523773          15.0                       2.0                         0.0
# 523774          30.0                       2.0                         0.0
# 523775          45.0                       0.0                         0.0
#
#         Total cycles
# 0                1.0
# 1                2.0
# 2                2.0
# 3                4.0
# 4                4.0
# ...              ...
# 523771           3.0
# 523772           2.0
# 523773           2.0
# 523774           2.0
# 523775           0.0
#
# [516536 rows x 13 columns]

# %%
il_drp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516536 entries, 0 to 523775
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Survey wave (year)          516536 non-null  float64
#  1   Site ID                     516536 non-null  object
#  2   Location                    516536 non-null  object
#  3   Survey date                 516536 non-null  object
#  4   Weather                     516536 non-null  object
#  5   Time                        516536 non-null  object
#  6   Period                      516536 non-null  object
#  7   Direction                   516536 non-null  object
#  8   Start hour                  516536 non-null  float64
#  9   Start minute                516536 non-null  float64
#  10  Number of private cycles    516536 non-null  float64
#  11  Number of cycle hire bikes  516536 non-null  float64
#  12  Total cycles                516536 non-null  float64
# dtypes: float64(6), object(7)
# memory usage: 55.2+ MB

# %%
il_drp[['Start_time', 'End_time']] = il_drp['Time'].str.split(" - ", expand=True)
il_drp['Start_time'] = pd.to_datetime(il_drp['Start_time'], format='%H%M')
il_drp['End_time'] = pd.to_datetime(il_drp['End_time'], format='%H%M')
il_drp['Duration'] = il_drp['End_time'] - il_drp['Start_time']

# %%
il_drp['Start_time'] = il_drp['Start_time'].apply(lambda x: x.time())
il_drp['End_time'] = il_drp['End_time'].apply(lambda x: x.time())

# %%
# Duration in miniutes.
il_drp['Duration_min'] = il_drp['Duration'].dt.total_seconds()/60

# %%
# check the column as to why it is not splitting from this 'mer, 24/01/14'.
pd.to_datetime(il_drp['Survey date'], errors='coerce')
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 523771   NaT
# 523772   NaT
# 523773   NaT
# 523774   NaT
# 523775   NaT
# Name: Survey date, Length: 516536, dtype: datetime64[ns]

# %%
# To remove spaces from the start and end of the strings.
il_drp['Survey date'] = il_drp['Survey date'].str.strip()

# %%
# Removing the 1st 4 characters in Survey Date.
il_drp["Survey date"] = il_drp["Survey date"].str[4:]

# %%
# Converting non-matching formats to NaT
il_drp["Survey date"] = pd.to_datetime(il_drp["Survey date"], errors='coerce')

# %%
# Count the number of missing values in the 'Survey date' column
missing_values = il_drp['Survey date'].isnull().sum()
print(missing_values)
# Out:
# 0

# %%
#converting to datetime format.
il_drp["Survey date"] = pd.to_datetime(il_drp["Survey date"], format='%d/%m/%y', errors='coerce')

# %%
# Splitting date into day, month, year.
il_drp['day'] = pd.DatetimeIndex(il_drp['Survey date']).day
il_drp['month'] = pd.DatetimeIndex(il_drp['Survey date']).month
il_drp['year'] = pd.DatetimeIndex(il_drp['Survey date']).year

# %%
# Changing to all lower case.
il_drp[['Weather']] = il_drp[['Weather']].apply(lambda x: x.str.lower())

# %%
il_drp
# Out:
#         Survey wave (year)   Site ID       Location Survey date Weather  \
# 0                   2015.0  INNCY001     Grove Road  2015-05-20     dry
# 1                   2015.0  INNCY001     Grove Road  2015-05-20     dry
# 2                   2015.0  INNCY001     Grove Road  2015-05-20     dry
# 3                   2015.0  INNCY001     Grove Road  2015-05-20     dry
# 4                   2015.0  INNCY001     Grove Road  2015-05-20     dry
# ...                    ...       ...            ...         ...     ...
# 523771              2021.0  INNCY597  Augustus Road  2021-05-26     dry
# 523772              2021.0  INNCY597  Augustus Road  2021-05-26     dry
# 523773              2021.0  INNCY597  Augustus Road  2021-05-26     dry
# 523774              2021.0  INNCY597  Augustus Road  2021-05-26     dry
# 523775              2021.0  INNCY597  Augustus Road  2021-05-26     dry
#
#                Time                       Period   Direction  Start hour  \
# 0       0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1       0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2       0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3       0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4       0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
# ...             ...                          ...         ...         ...
# 523771  2045 - 2100        Evening (19:00-22:00)   Westbound        20.0
# 523772  2100 - 2115        Evening (19:00-22:00)   Westbound        21.0
# 523773  2115 - 2130        Evening (19:00-22:00)   Westbound        21.0
# 523774  2130 - 2145        Evening (19:00-22:00)   Westbound        21.0
# 523775  2145 - 2200        Evening (19:00-22:00)   Westbound        21.0
#
#         Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0                0.0                       1.0                         0.0
# 1               15.0                       2.0                         0.0
# 2               30.0                       2.0                         0.0
# 3               45.0                       4.0                         0.0
# 4                0.0                       4.0                         0.0
# ...              ...                       ...                         ...
# 523771          45.0                       3.0                         0.0
# 523772           0.0                       2.0                         0.0
# 523773          15.0                       2.0                         0.0
# 523774          30.0                       2.0                         0.0
# 523775          45.0                       0.0                         0.0
#
#         Total cycles Start_time  End_time        Duration  Duration_min  day  \
# 0                1.0   06:00:00  06:15:00 0 days 00:15:00          15.0   20
# 1                2.0   06:15:00  06:30:00 0 days 00:15:00          15.0   20
# 2                2.0   06:30:00  06:45:00 0 days 00:15:00          15.0   20
# 3                4.0   06:45:00  07:00:00 0 days 00:15:00          15.0   20
# 4                4.0   07:00:00  07:15:00 0 days 00:15:00          15.0   20
# ...              ...        ...       ...             ...           ...  ...
# 523771           3.0   20:45:00  21:00:00 0 days 00:15:00          15.0   26
# 523772           2.0   21:00:00  21:15:00 0 days 00:15:00          15.0   26
# 523773           2.0   21:15:00  21:30:00 0 days 00:15:00          15.0   26
# 523774           2.0   21:30:00  21:45:00 0 days 00:15:00          15.0   26
# 523775           0.0   21:45:00  22:00:00 0 days 00:15:00          15.0   26
#
#         month  year
# 0           5  2015
# 1           5  2015
# 2           5  2015
# 3           5  2015
# 4           5  2015
# ...       ...   ...
# 523771      5  2021
# 523772      5  2021
# 523773      5  2021
# 523774      5  2021
# 523775      5  2021
#
# [516536 rows x 20 columns]

# %%
# Dropping the columns which is not required.
il_drp = il_drp.drop(['Survey wave (year)', 'Survey date',
                     'Time', 'Start hour', 'Start minute', 'Duration'], axis=1)

# %%
il_drp['Weather'].unique()
# Out:
# array(['dry', 'dry                         9', 'wet', 'warm + dry',
#        's.wet', 's/w', 'sunny', 'cloudy/sunny', 'cloudy', 'cloudy/rain',
#        'cloudy/dry', 'rain', 'druy', 'mix wet/dry', 'drizzle',
#        'dry & windy', 'light showers', 'dry/hot', 'sun', 'fine',
#        'very windy', 'mizzle', 'windy/rain', 'dry warm', 'showers',
#        'wet/dry', 'high wind', 'dry wet road', 'wet/damp', 'dry/sunny',
#        'dark/cloudy', 'shower', 'dry/sun', 'dry/overcast', 'overcast',
#        'light rain', 'shower/dry', 'down pour', 'sleet', 'wet (shower)',
#        'spitting', 'dry sunny', 'heavy rain', 'drizzle/cloudy', 'dry/wet',
#        'dull', 'damp', 'cloud', 'dry/drizzle', 'fair', 'rain/sleet',
#        'dry cold', 'dull/damp', 'hail stone', 'hot', 'dry-wet', 'n/a',
#        'too cold', 'overcast/dry', 'bright/dry',
#        'overcast/rain heavy showers', 'heavy thunder', 'wet/mix',
#        'thunder', 'sun/cloudy', 'snow', 'dry/cloudy',
#        'dry road still wet', 'windy', 'drizzle/wet', 'sunny (hot!)',
#        'wet/windy', 'dry/v. windy', 'warm/dry', 'rain shower',
#        'intermittent showers', 'cloudy/drizzle', 'rain/drizzle',
#        'cloudy/sun', 'cloudy sun', 'hail', 'wet road', 'dry/cold',
#        'drizzle/dry', 'drizzle/rain', 'd', 'mixed sunny + rain',
#        'wet/rain', 'rain heavy', 'v wet', 'v light drizzle',
#        'sunny/cloudy', 'rainy', 'w', 'heavy rain high winds', 'dry windy',
#        'rain stopped', 'slight drizzle', 'stopped raining', 'sun/cloud',
#        'mixed', 'storm', 'dry y', 'dr ry', 'sunny/dry', 'dry + sunny',
#        'wet rain stopped', 'cold', 'hot/dry', 'very hot/dry',
#        'raining/wet', 'cloud/sun', 'showery', 'overcast/rain', 'rain/wet',
#        'rain/showers', 'showers/sunny', 'drizzle/showers',
#        'slight drizzle/dry', 'wet/stop raining', 'drizzle rain',
#        'drizzle wet', 'cloudy dry', 'school out', 'clear',
#        'heavy showers', 'showers/hailstone', 'sun & clouds', 'damp/sun',
#        'rain/hailstone', 'cloudy & sunny', 'sun/clouds',
#        'intermittent heavy showers', 'very heavy rain', 'raining',
#        'windy at first then sunny', 'sunny & warm all day', 'dry + wet',
#        'showers/cloudy', 'cloudy/showers', 'getting wet',
#        'clouds & sunny', 'wet road:sun', 'dry but wet road', 'drizze',
#        'bright', 'dry but misty', 'clear and warm', 'windy dry',
#        'partly cloudy and dry', 'cloudy but dry', 'partly cloudy but dry',
#        'unknown', 'cloudy with clear intervals', 'dry, sunny, warm',
#        'dry, sunny, hot', 'dry, warm', 'clear and dry', 'cloudy and dry',
#        'dryish', 'wettish'], dtype=object)

# %%
# create a new column with the category
il_drp['Category'] = 'Other'
il_drp.loc[il_drp['Weather'].str.contains(
    'wet|rain|thunder|shower|drizzly|drizzle|deluge|hail', case=False), 'Category'] = 'Wet'
il_drp.loc[il_drp['Weather'].str.contains(
    'dry|sun|clear', case=False), 'Category'] = 'Dry'
il_drp.loc[il_drp['Weather'].str.contains(
    'wind|gale|windy', case=False), 'Category'] = 'Windy'

# %%
# Creating a new column
il_drp = il_drp.assign(area='Inner London')

# %%
# Checking the data frame.
il_drp
# Out:
#          Site ID       Location Weather                       Period  \
# 0       INNCY001     Grove Road     dry  Early Morning (06:00-07:00)
# 1       INNCY001     Grove Road     dry  Early Morning (06:00-07:00)
# 2       INNCY001     Grove Road     dry  Early Morning (06:00-07:00)
# 3       INNCY001     Grove Road     dry  Early Morning (06:00-07:00)
# 4       INNCY001     Grove Road     dry        AM peak (07:00-10:00)
# ...          ...            ...     ...                          ...
# 523771  INNCY597  Augustus Road     dry        Evening (19:00-22:00)
# 523772  INNCY597  Augustus Road     dry        Evening (19:00-22:00)
# 523773  INNCY597  Augustus Road     dry        Evening (19:00-22:00)
# 523774  INNCY597  Augustus Road     dry        Evening (19:00-22:00)
# 523775  INNCY597  Augustus Road     dry        Evening (19:00-22:00)
#
#          Direction  Number of private cycles  Number of cycle hire bikes  \
# 0       Northbound                       1.0                         0.0
# 1       Northbound                       2.0                         0.0
# 2       Northbound                       2.0                         0.0
# 3       Northbound                       4.0                         0.0
# 4       Northbound                       4.0                         0.0
# ...            ...                       ...                         ...
# 523771   Westbound                       3.0                         0.0
# 523772   Westbound                       2.0                         0.0
# 523773   Westbound                       2.0                         0.0
# 523774   Westbound                       2.0                         0.0
# 523775   Westbound                       0.0                         0.0
#
#         Total cycles Start_time  End_time  Duration_min  day  month  year  \
# 0                1.0   06:00:00  06:15:00          15.0   20      5  2015
# 1                2.0   06:15:00  06:30:00          15.0   20      5  2015
# 2                2.0   06:30:00  06:45:00          15.0   20      5  2015
# 3                4.0   06:45:00  07:00:00          15.0   20      5  2015
# 4                4.0   07:00:00  07:15:00          15.0   20      5  2015
# ...              ...        ...       ...           ...  ...    ...   ...
# 523771           3.0   20:45:00  21:00:00          15.0   26      5  2021
# 523772           2.0   21:00:00  21:15:00          15.0   26      5  2021
# 523773           2.0   21:15:00  21:30:00          15.0   26      5  2021
# 523774           2.0   21:30:00  21:45:00          15.0   26      5  2021
# 523775           0.0   21:45:00  22:00:00          15.0   26      5  2021
#
#        Category          area
# 0           Dry  Inner London
# 1           Dry  Inner London
# 2           Dry  Inner London
# 3           Dry  Inner London
# 4           Dry  Inner London
# ...         ...           ...
# 523771      Dry  Inner London
# 523772      Dry  Inner London
# 523773      Dry  Inner London
# 523774      Dry  Inner London
# 523775      Dry  Inner London
#
# [516536 rows x 16 columns]

# %%
il_drp['Category'].value_counts()
# Out:
# Dry      446357
# Wet       60357
# Other      9426
# Windy       396
# Name: Category, dtype: int64

# %% [markdown]
# ### Outer London data set.

# %%
# Importing Outer London dataset.
ol = pd.read_csv('Outer London.csv')

# View the DataFrame.
ol
# Out:
#         Survey wave (year)   Site ID                      Location  \
# 0                     2015  OUTCY001              High Road Leyton
# 1                     2015  OUTCY001              High Road Leyton
# 2                     2015  OUTCY001              High Road Leyton
# 3                     2015  OUTCY001              High Road Leyton
# 4                     2015  OUTCY001              High Road Leyton
# ...                    ...       ...                           ...
# 375655                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375656                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375657                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375658                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375659                2021  OUTCY451  Thames Path (Lower Ham Road)
#
#           Survey date Weather         Time                       Period  \
# 0       ven, 26/06/15     Dry  0600 - 0615  Early Morning (06:00-07:00)
# 1       ven, 26/06/15     Dry  0615 - 0630  Early Morning (06:00-07:00)
# 2       ven, 26/06/15     Dry  0630 - 0645  Early Morning (06:00-07:00)
# 3       ven, 26/06/15     Dry  0645 - 0700  Early Morning (06:00-07:00)
# 4       ven, 26/06/15     Dry  0700 - 0715        AM peak (07:00-10:00)
# ...               ...     ...          ...                          ...
# 375655  ven, 18/06/21     Wet  2045 - 2100        Evening (19:00-22:00)
# 375656  ven, 18/06/21     Wet  2100 - 2115        Evening (19:00-22:00)
# 375657  ven, 18/06/21     Wet  2115 - 2130        Evening (19:00-22:00)
# 375658  ven, 18/06/21     Wet  2130 - 2145        Evening (19:00-22:00)
# 375659  ven, 18/06/21     Wet  2145 - 2200        Evening (19:00-22:00)
#
#          Direction  Start hour  Start minute  Number of male cycles  \
# 0       Northbound           6             0                      2
# 1       Northbound           6            15                      3
# 2       Northbound           6            30                      2
# 3       Northbound           6            45                      4
# 4       Northbound           7             0                      4
# ...            ...         ...           ...                    ...
# 375655  Southbound          20            45                      1
# 375656  Southbound          21             0                      2
# 375657  Southbound          21            15                      0
# 375658  Southbound          21            30                      0
# 375659  Southbound          21            45                      1
#
#         Number of female cycles  Number of unknown cycles  Total cycles
# 0                             1                         0             3
# 1                             0                         0             3
# 2                             0                         0             2
# 3                             0                         0             4
# 4                             1                         0             5
# ...                         ...                       ...           ...
# 375655                        0                         0             1
# 375656                        0                         0             2
# 375657                        0                         0             0
# 375658                        0                         0             0
# 375659                        0                         0             1
#
# [375660 rows x 14 columns]

# %%
ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375660 entries, 0 to 375659
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Survey wave (year)        375660 non-null  int64
#  1   Site ID                   375660 non-null  object
#  2   Location                  375660 non-null  object
#  3   Survey date               374492 non-null  object
#  4   Weather                   374692 non-null  object
#  5   Time                      375660 non-null  object
#  6   Period                    375660 non-null  object
#  7   Direction                 375660 non-null  object
#  8   Start hour                375660 non-null  int64
#  9   Start minute              375660 non-null  int64
#  10  Number of male cycles     375660 non-null  int64
#  11  Number of female cycles   375660 non-null  int64
#  12  Number of unknown cycles  375660 non-null  int64
#  13  Total cycles              375660 non-null  int64
# dtypes: int64(7), object(7)
# memory usage: 40.1+ MB

# %%
# Check & print missing values.
missing_values_ol = ol.isna().sum()
print(missing_values_ol)
# Out:
# Survey wave (year)             0
# Site ID                        0
# Location                       0
# Survey date                 1168
# Weather                      968
# Time                           0
# Period                         0
# Direction                      0
# Start hour                     0
# Start minute                   0
# Number of male cycles          0
# Number of female cycles        0
# Number of unknown cycles       0
# Total cycles                   0
# dtype: int64

# %%
# Impute missing values in "Survey date" column
# Compute the most common date
most_common_date = ol['Survey date'].mode()[0]
# Replace missing values with the most common date
ol['Survey date'] = ol['Survey date'].fillna(most_common_date)

# Impute missing values in "Weather" column
# Compute the most common weather category
most_common_weather = ol['Weather'].mode()[0]
# Replace missing values with the most common weather category
ol['Weather'] = ol['Weather'].fillna(most_common_weather)

# Check the missing value rate after imputation
missing_values2 = ol.isnull().sum()
print(missing_values2)
# Out:
# Survey wave (year)          0
# Site ID                     0
# Location                    0
# Survey date                 0
# Weather                     0
# Time                        0
# Period                      0
# Direction                   0
# Start hour                  0
# Start minute                0
# Number of male cycles       0
# Number of female cycles     0
# Number of unknown cycles    0
# Total cycles                0
# dtype: int64

# %%
# Check Dataframe
ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375660 entries, 0 to 375659
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Survey wave (year)        375660 non-null  int64
#  1   Site ID                   375660 non-null  object
#  2   Location                  375660 non-null  object
#  3   Survey date               375660 non-null  object
#  4   Weather                   375660 non-null  object
#  5   Time                      375660 non-null  object
#  6   Period                    375660 non-null  object
#  7   Direction                 375660 non-null  object
#  8   Start hour                375660 non-null  int64
#  9   Start minute              375660 non-null  int64
#  10  Number of male cycles     375660 non-null  int64
#  11  Number of female cycles   375660 non-null  int64
#  12  Number of unknown cycles  375660 non-null  int64
#  13  Total cycles              375660 non-null  int64
# dtypes: int64(7), object(7)
# memory usage: 40.1+ MB

# %%
ol[['Start_time', 'End_time']] = ol['Time'].str.split(" - ", expand=True)
ol['Start_time'] = pd.to_datetime(ol['Start_time'], format='%H%M')
ol['End_time'] = pd.to_datetime(ol['End_time'], format='%H%M')
ol['Duration'] = ol['End_time'] - ol['Start_time']

# %%
ol['Start_time'] = ol['Start_time'].apply(lambda x: x.time())
ol['End_time'] = ol['End_time'].apply(lambda x: x.time())

# %%
# Duration in miniutes.
ol['Duration_min'] = ol['Duration'].dt.total_seconds()/60

# %%
# To remove spaces from the start and end of the strings.
ol['Survey date'] = ol['Survey date'].str.strip()

# %%
# Removing the 1st 4 characters in Survey Date.
ol["Survey date"] = ol["Survey date"].str[4:]

# %%
# Converting non-matching formats to NaT
ol["Survey date"] = pd.to_datetime(ol["Survey date"], errors='coerce')

# %%
#converting to datetime format.
ol["Survey date"] = pd.to_datetime(ol["Survey date"], format='%d/%m/%y', errors='coerce')

# %%
# Splitting date into day, month, year.
ol['day'] = pd.DatetimeIndex(ol['Survey date']).day
ol['month'] = pd.DatetimeIndex(ol['Survey date']).month
ol['year'] = pd.DatetimeIndex(ol['Survey date']).year

# %%
# Changing to all lower case.
ol[['Weather']] = ol[['Weather']].apply(lambda x: x.str.lower())

# %%
ol['Weather'].unique()
# Out:
# array(['dry', 'wet', 'showers', 'cloudy', 'rain', 'dry chill', 'sunny',
#        'cloudy sunny', 'sun setting', 'dry/cold', 'dry cold',
#        'cold/sunny', 'cold/cloudy', 'sunny overcast', 'sunny/cloudy',
#        'dry dark', 'fine', 'good', 'dry very windy', 'wet/dry',
#        'cloudy/rain/sunny', 'cloudy + sunny', 'sunny + cloudy',
#        'dry/sunny', 'dry/windy', 'wet/windy', 'wet/v.windy', 'fine + dry',
#        'fine + hot', 'cloudy/sunny', 'dry/dark', 'dry/good', 'fine/dry',
#        'warm + dry', 'windy', 'bright + cloudy', 'dark/dry', 'cloudy/dry',
#        'cloudy + rain', 'rain & cloudy', 'raining', 'dry/mild', 'cold',
#        'partly sunny', 'rain/cloudy', 'cloudy/windy', 'windy + sunny',
#        'sunsetting + windy', 'dark cloudy', 'dark dry', 'bright', 'dull',
#        'heavy rain', 'n/a', 'intermittent light drizzle', 'heavy shower',
#        'light rain', 'dry hot!!', 'lt rain', 'heavy shr', 'dry & sunny',
#        'dry/wet road', 'dry with wet road', 'dry/wet', 'dry & sun',
#        'drizzle', 'down pour', 'deluge', 'wet/thunder', 'dry & mild',
#        'hot', 'fine & dry', 'dry v. cold!', 'wet hail', 'heavy showers',
#        'shower', 'rain/hail', 'rain heavy showers', 'snow!', 'snow',
#        'intermitent showers', 'clear', 'intermittent drizzle',
#        'light showers', 'sleet', 'foggy wet', 'thunder lightening rain!',
#        'very wet', 'wet heavy wind', 'v.wet', 'good/dry', 'very cool',
#        'heavy downpour/rain', 'wet-windy', 'showery', 'rain/showers',
#        'very hot', 'wet heavy rain', 'dry (road wet)', 'damp', 'sun',
#        'cloud', 'wet (heavy rain)', 'd', 'w', 'wey', 'drizzle/shower',
#        'hailstones', 'getting dry', 'rainy', 'mild', 'sunny dry',
#        'overcast', 'short hail shower', 'dry & wet', 'clear and bright',
#        'overcast (no rain)', 'unknown', 'cloudy bright intervals',
#        'cloudy with showers', 'generally overcast brief shower',
#        'generally overcast', 'cloudy with clear spells'], dtype=object)

# %%
# create a new column with the category
ol['Category'] = 'Other'
ol.loc[ol['Weather'].str.contains(
    'wet|rain|thunder|shower|drizzly|drizzle|deluge|hail', case=False), 'Category'] = 'Wet'
ol.loc[ol['Weather'].str.contains(
    'dry|sun|clear', case=False), 'Category'] = 'Dry'
ol.loc[ol['Weather'].str.contains(
    'wind|gale|windy', case=False), 'Category'] = 'Windy'

# %%
ol['Category'].value_counts()
# Out:
# Dry      328169
# Wet       42803
# Other      4214
# Windy       474
# Name: Category, dtype: int64

# %%
ol
# Out:
#         Survey wave (year)   Site ID                      Location  \
# 0                     2015  OUTCY001              High Road Leyton
# 1                     2015  OUTCY001              High Road Leyton
# 2                     2015  OUTCY001              High Road Leyton
# 3                     2015  OUTCY001              High Road Leyton
# 4                     2015  OUTCY001              High Road Leyton
# ...                    ...       ...                           ...
# 375655                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375656                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375657                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375658                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375659                2021  OUTCY451  Thames Path (Lower Ham Road)
#
#        Survey date Weather         Time                       Period  \
# 0       2015-06-26     dry  0600 - 0615  Early Morning (06:00-07:00)
# 1       2015-06-26     dry  0615 - 0630  Early Morning (06:00-07:00)
# 2       2015-06-26     dry  0630 - 0645  Early Morning (06:00-07:00)
# 3       2015-06-26     dry  0645 - 0700  Early Morning (06:00-07:00)
# 4       2015-06-26     dry  0700 - 0715        AM peak (07:00-10:00)
# ...            ...     ...          ...                          ...
# 375655  2021-06-18     wet  2045 - 2100        Evening (19:00-22:00)
# 375656  2021-06-18     wet  2100 - 2115        Evening (19:00-22:00)
# 375657  2021-06-18     wet  2115 - 2130        Evening (19:00-22:00)
# 375658  2021-06-18     wet  2130 - 2145        Evening (19:00-22:00)
# 375659  2021-06-18     wet  2145 - 2200        Evening (19:00-22:00)
#
#          Direction  Start hour  Start minute  ...  Number of unknown cycles  \
# 0       Northbound           6             0  ...                         0
# 1       Northbound           6            15  ...                         0
# 2       Northbound           6            30  ...                         0
# 3       Northbound           6            45  ...                         0
# 4       Northbound           7             0  ...                         0
# ...            ...         ...           ...  ...                       ...
# 375655  Southbound          20            45  ...                         0
# 375656  Southbound          21             0  ...                         0
# 375657  Southbound          21            15  ...                         0
# 375658  Southbound          21            30  ...                         0
# 375659  Southbound          21            45  ...                         0
#
#         Total cycles  Start_time  End_time        Duration Duration_min day  \
# 0                  3    06:00:00  06:15:00 0 days 00:15:00         15.0  26
# 1                  3    06:15:00  06:30:00 0 days 00:15:00         15.0  26
# 2                  2    06:30:00  06:45:00 0 days 00:15:00         15.0  26
# 3                  4    06:45:00  07:00:00 0 days 00:15:00         15.0  26
# 4                  5    07:00:00  07:15:00 0 days 00:15:00         15.0  26
# ...              ...         ...       ...             ...          ...  ..
# 375655             1    20:45:00  21:00:00 0 days 00:15:00         15.0  18
# 375656             2    21:00:00  21:15:00 0 days 00:15:00         15.0  18
# 375657             0    21:15:00  21:30:00 0 days 00:15:00         15.0  18
# 375658             0    21:30:00  21:45:00 0 days 00:15:00         15.0  18
# 375659             1    21:45:00  22:00:00 0 days 00:15:00         15.0  18
#
#         month  year  Category
# 0           6  2015       Dry
# 1           6  2015       Dry
# 2           6  2015       Dry
# 3           6  2015       Dry
# 4           6  2015       Dry
# ...       ...   ...       ...
# 375655      6  2021       Wet
# 375656      6  2021       Wet
# 375657      6  2021       Wet
# 375658      6  2021       Wet
# 375659      6  2021       Wet
#
# [375660 rows x 22 columns]

# %%
# Dropping the columns which is not required.
ol = ol.drop(['Survey wave (year)', 'Survey date',
                     'Time', 'Start hour', 'Start minute', 'Duration'], axis=1)

# %%
# Creating a new column
ol = ol.assign(area='Outer London')

# %%
# Check the dataframe.
ol
# Out:
#          Site ID                      Location Weather  \
# 0       OUTCY001              High Road Leyton     dry
# 1       OUTCY001              High Road Leyton     dry
# 2       OUTCY001              High Road Leyton     dry
# 3       OUTCY001              High Road Leyton     dry
# 4       OUTCY001              High Road Leyton     dry
# ...          ...                           ...     ...
# 375655  OUTCY451  Thames Path (Lower Ham Road)     wet
# 375656  OUTCY451  Thames Path (Lower Ham Road)     wet
# 375657  OUTCY451  Thames Path (Lower Ham Road)     wet
# 375658  OUTCY451  Thames Path (Lower Ham Road)     wet
# 375659  OUTCY451  Thames Path (Lower Ham Road)     wet
#
#                              Period   Direction  Number of male cycles  \
# 0       Early Morning (06:00-07:00)  Northbound                      2
# 1       Early Morning (06:00-07:00)  Northbound                      3
# 2       Early Morning (06:00-07:00)  Northbound                      2
# 3       Early Morning (06:00-07:00)  Northbound                      4
# 4             AM peak (07:00-10:00)  Northbound                      4
# ...                             ...         ...                    ...
# 375655        Evening (19:00-22:00)  Southbound                      1
# 375656        Evening (19:00-22:00)  Southbound                      2
# 375657        Evening (19:00-22:00)  Southbound                      0
# 375658        Evening (19:00-22:00)  Southbound                      0
# 375659        Evening (19:00-22:00)  Southbound                      1
#
#         Number of female cycles  Number of unknown cycles  Total cycles  \
# 0                             1                         0             3
# 1                             0                         0             3
# 2                             0                         0             2
# 3                             0                         0             4
# 4                             1                         0             5
# ...                         ...                       ...           ...
# 375655                        0                         0             1
# 375656                        0                         0             2
# 375657                        0                         0             0
# 375658                        0                         0             0
# 375659                        0                         0             1
#
#        Start_time  End_time  Duration_min  day  month  year Category  \
# 0        06:00:00  06:15:00          15.0   26      6  2015      Dry
# 1        06:15:00  06:30:00          15.0   26      6  2015      Dry
# 2        06:30:00  06:45:00          15.0   26      6  2015      Dry
# 3        06:45:00  07:00:00          15.0   26      6  2015      Dry
# 4        07:00:00  07:15:00          15.0   26      6  2015      Dry
# ...           ...       ...           ...  ...    ...   ...      ...
# 375655   20:45:00  21:00:00          15.0   18      6  2021      Wet
# 375656   21:00:00  21:15:00          15.0   18      6  2021      Wet
# 375657   21:15:00  21:30:00          15.0   18      6  2021      Wet
# 375658   21:30:00  21:45:00          15.0   18      6  2021      Wet
# 375659   21:45:00  22:00:00          15.0   18      6  2021      Wet
#
#                 area
# 0       Outer London
# 1       Outer London
# 2       Outer London
# 3       Outer London
# 4       Outer London
# ...              ...
# 375655  Outer London
# 375656  Outer London
# 375657  Outer London
# 375658  Outer London
# 375659  Outer London
#
# [375660 rows x 17 columns]

# %% [markdown]
# ## Merging the 3 dataframes

# %% [markdown]
# ##### Dropping few columns in all 3 dataframe before merging.
#
# - Central London :	Number of private cycles,	Number of cycle hire bikes
# - Inner	Lonond  :    Number of private cycles,	Number of cycle hire bikes
# - Outer	 London  :   Number of male cycles,	    Number of female cycles,	    Number of unknown cycles

# %%
# Dropping the columns in Central London dataframe.
cl_drp_new = cl_drp.drop(['Number of private cycles', 'Number of cycle hire bikes'], axis=1)

# %%
# Dropping the columns in Inner London dataframe.
il_drp_new = il_drp.drop(['Number of private cycles', 'Number of cycle hire bikes'], axis=1)

# %%
# Dropping the columns in Outer London dataframe.
ol_new = ol.drop(['Number of male cycles', 'Number of female cycles',
             'Number of unknown cycles'], axis=1)

# %%
# Shape of the dataframes
print("Central London",cl_drp_new.shape)
print("Inner London",il_drp_new.shape)
print("Outer London",ol_new.shape)
# Out:
# Central London (743061, 14)
# Inner London (516536, 14)
# Outer London (375660, 14)

# %%
# Merging dataframes.
frames = [cl_drp_new, il_drp_new, ol_new]
merged_cycle_df = pd.concat(frames).reset_index()

# %%
# Checking the merged dataframe.
merged_cycle_df
# Out:
#           index   Site ID                            Location Weather  \
# 0             0  CENCY001  Millbank (south of Thorney Street)     dry
# 1             1  CENCY001  Millbank (south of Thorney Street)     dry
# 2             2  CENCY001  Millbank (south of Thorney Street)     dry
# 3             3  CENCY001  Millbank (south of Thorney Street)     dry
# 4             4  CENCY001  Millbank (south of Thorney Street)     dry
# ...         ...       ...                                 ...     ...
# 1635252  375655  OUTCY451        Thames Path (Lower Ham Road)     wet
# 1635253  375656  OUTCY451        Thames Path (Lower Ham Road)     wet
# 1635254  375657  OUTCY451        Thames Path (Lower Ham Road)     wet
# 1635255  375658  OUTCY451        Thames Path (Lower Ham Road)     wet
# 1635256  375659  OUTCY451        Thames Path (Lower Ham Road)     wet
#
#                               Period   Direction  Total cycles Start_time  \
# 0        Early Morning (06:00-07:00)  Northbound           0.0   06:00:00
# 1        Early Morning (06:00-07:00)  Northbound          15.0   06:15:00
# 2        Early Morning (06:00-07:00)  Northbound          35.0   06:30:00
# 3        Early Morning (06:00-07:00)  Northbound          61.0   06:45:00
# 4              AM peak (07:00-10:00)  Northbound          73.0   07:00:00
# ...                              ...         ...           ...        ...
# 1635252        Evening (19:00-22:00)  Southbound           1.0   20:45:00
# 1635253        Evening (19:00-22:00)  Southbound           2.0   21:00:00
# 1635254        Evening (19:00-22:00)  Southbound           0.0   21:15:00
# 1635255        Evening (19:00-22:00)  Southbound           0.0   21:30:00
# 1635256        Evening (19:00-22:00)  Southbound           1.0   21:45:00
#
#          End_time  Duration_min  day  month  year Category            area
# 0        06:15:00          15.0   24      1  2014      Dry  Central London
# 1        06:30:00          15.0   24      1  2014      Dry  Central London
# 2        06:45:00          15.0   24      1  2014      Dry  Central London
# 3        07:00:00          15.0   24      1  2014      Dry  Central London
# 4        07:15:00          15.0   24      1  2014      Dry  Central London
# ...           ...           ...  ...    ...   ...      ...             ...
# 1635252  21:00:00          15.0   18      6  2021      Wet    Outer London
# 1635253  21:15:00          15.0   18      6  2021      Wet    Outer London
# 1635254  21:30:00          15.0   18      6  2021      Wet    Outer London
# 1635255  21:45:00          15.0   18      6  2021      Wet    Outer London
# 1635256  22:00:00          15.0   18      6  2021      Wet    Outer London
#
# [1635257 rows x 15 columns]
